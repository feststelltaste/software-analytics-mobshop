# %% [markdown]
# # Production Coverage Analysis
#
# ## Context
#
# Developers of the Java application "Spring PetClinic" said, that there would be much code that isn't used at all. Before migrating the application to the new platform, an analysis should find out, which parts of the system are still in use and which are not (and may be deleted safely).

# %% [markdown]
# ## I. Stating Question

# %% [markdown]
# ## II. Exploratory Data Analysis

# %%
import pandas as pd

df = pd.read_csv("../datasets/jacoco_production_measure_messy.csv", sep=";")
df[['package', 'class']] = df['FQN'].str.rsplit(".", n=1, expand=True)
df
# Out:
#                                                   FQN  LINE_MISSED  \
# 0   org.springframework.samples.petclinic.Petclini...            0
# 1   org.springframework.samples.petclinic.model.Na...            1
# 2   org.springframework.samples.petclinic.model.Sp...            0
# 3   org.springframework.samples.petclinic.model.Pe...            0
# 4    org.springframework.samples.petclinic.model.Vets            3
# 5   org.springframework.samples.petclinic.model.Visit            0
# 6   org.springframework.samples.petclinic.model.Ba...            0
# 7   org.springframework.samples.petclinic.model.Pe...            0
# 8   org.springframework.samples.petclinic.model.Owner           10
# 9     org.springframework.samples.petclinic.model.Pet            3
# 10    org.springframework.samples.petclinic.model.Vet            1
# 11  org.springframework.samples.petclinic.service....            2
# 12  org.springframework.samples.petclinic.web.Owne...           10
# 13  org.springframework.samples.petclinic.web.PetT...            1
# 14  org.springframework.samples.petclinic.web.PetC...           10
# 15  org.springframework.samples.petclinic.web.PetV...            3
# 16  org.springframework.samples.petclinic.web.Visi...            3
# 17  org.springframework.samples.petclinic.web.VetC...            7
# 18  org.springframework.samples.petclinic.web.Cras...            1
# 19  org.springframework.samples.petclinic.util.Ent...            6
# 20  org.springframework.samples.petclinic.util.Cal...           11
# 21  org.springframework.samples.petclinic.reposito...            7
# 22  org.springframework.samples.petclinic.reposito...           33
# 23  org.springframework.samples.petclinic.reposito...           17
# 24  org.springframework.samples.petclinic.reposito...            9
# 25  org.springframework.samples.petclinic.reposito...           26
# 26  org.springframework.samples.petclinic.reposito...            7
# 27  org.springframework.samples.petclinic.reposito...            8
# 28  org.springframework.samples.petclinic.reposito...           43
# 29  org.springframework.samples.petclinic.reposito...            4
# 30  org.springframework.samples.petclinic.reposito...            2
# 31  org.springframework.samples.petclinic.reposito...            0
# 32  org.springframework.samples.petclinic.reposito...            1
#
#     LINE_COVERED                                            package  \
# 0             24              org.springframework.samples.petclinic
# 1              4        org.springframework.samples.petclinic.model
# 2              1        org.springframework.samples.petclinic.model
# 3              1        org.springframework.samples.petclinic.model
# 4              1        org.springframework.samples.petclinic.model
# 5             12        org.springframework.samples.petclinic.model
# 6              5        org.springframework.samples.petclinic.model
# 7              7        org.springframework.samples.petclinic.model
# 8             30        org.springframework.samples.petclinic.model
# 9             18        org.springframework.samples.petclinic.model
# 10            10        org.springframework.samples.petclinic.model
# 11            16      org.springframework.samples.petclinic.service
# 12            26          org.springframework.samples.petclinic.web
# 13             9          org.springframework.samples.petclinic.web
# 14            20          org.springframework.samples.petclinic.web
# 15             8          org.springframework.samples.petclinic.web
# 16            13          org.springframework.samples.petclinic.web
# 17             3          org.springframework.samples.petclinic.web
# 18             1          org.springframework.samples.petclinic.web
# 19             0         org.springframework.samples.petclinic.util
# 20            13         org.springframework.samples.petclinic.util
# 21             0  org.springframework.samples.petclinic.reposito...
# 22             0  org.springframework.samples.petclinic.reposito...
# 23             0  org.springframework.samples.petclinic.reposito...
# 24             0  org.springframework.samples.petclinic.reposito...
# 25             0  org.springframework.samples.petclinic.reposito...
# 26             0  org.springframework.samples.petclinic.reposito...
# 27             0  org.springframework.samples.petclinic.reposito...
# 28             0  org.springframework.samples.petclinic.reposito...
# 29             4  org.springframework.samples.petclinic.reposito...
# 30             8  org.springframework.samples.petclinic.reposito...
# 31             2  org.springframework.samples.petclinic.reposito...
# 32             6  org.springframework.samples.petclinic.reposito...
#
#                       class
# 0      PetclinicInitializer
# 1               NamedEntity
# 2                 Specialty
# 3                   PetType
# 4                      Vets
# 5                     Visit
# 6                BaseEntity
# 7                    Person
# 8                     Owner
# 9                       Pet
# 10                      Vet
# 11        ClinicServiceImpl
# 12          OwnerController
# 13         PetTypeFormatter
# 14            PetController
# 15             PetValidator
# 16          VisitController
# 17            VetController
# 18          CrashController
# 19              EntityUtils
# 20     CallMonitoringAspect
# 21       JdbcVisitRowMapper
# 22    JdbcPetRepositoryImpl
# 23    JdbcVetRepositoryImpl
# 24         JdbcPetRowMapper
# 25  JdbcVisitRepositoryImpl
# 26                  JdbcPet
# 27    JdbcPetVisitExtractor
# 28  JdbcOwnerRepositoryImpl
# 29   JpaVisitRepositoryImpl
# 30   JpaOwnerRepositoryImpl
# 31     JpaVetRepositoryImpl
# 32     JpaPetRepositoryImpl

# %% [markdown]
# ## III. Formal Modelling

# %% [markdown]
# ## IV. Interpretation

# %% [markdown]
# ## V. Communication
